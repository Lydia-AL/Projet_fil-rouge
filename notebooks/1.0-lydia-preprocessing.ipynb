# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/frobi/OneDrive/Documents/GitHub/dec23_cds_co2/data/raw/data.csv")
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\4073366774.py:1: DtypeWarning: Columns (3,8,10,12,28,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C:/Users/frobi/OneDrive/Documents/GitHub/dec23_cds_co2/data/raw/data.csv")

# %%
data.head()
# Out:
#          ID Country                       VFN                         Mp  \
# 0  77074136      FR  IP-07A1A1E024A_000-VF1-1  RENAULT-NISSAN-MITSUBISHI
# 1  77074137      FR  IP-07A1A1E024A_000-VF1-1  RENAULT-NISSAN-MITSUBISHI
# 2  77074138      FR  IP-07A1A1E024A_000-VF1-1  RENAULT-NISSAN-MITSUBISHI
# 3  77074139      FR  IP-07A1A1E024A_000-VF1-1  RENAULT-NISSAN-MITSUBISHI
# 4  77074140      FR  IP-07A1A1E024A_000-VF1-1  RENAULT-NISSAN-MITSUBISHI
#
#         Mh          Man  MMS                 Tan   T    Va  ...   IT  \
# 0  RENAULT  RENAULT SAS  NaN  e2*2007/46*0457*23  AH  2BV2  ...  NaN
# 1  RENAULT  RENAULT SAS  NaN  e2*2007/46*0457*22  AH  2BV2  ...  NaN
# 2  RENAULT  RENAULT SAS  NaN  e2*2007/46*0457*22  AH  2BV2  ...  NaN
# 3  RENAULT  RENAULT SAS  NaN  e2*2007/46*0457*22  AH  2BV2  ...  NaN
# 4  RENAULT  RENAULT SAS  NaN  e2*2007/46*0457*23  AH  2BV2  ...  NaN
#
#   Ernedc (g/km) Erwltp (g/km)  De  Vf  Status  year  Date of registration  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9479544 entries, 0 to 9479543
# Data columns (total 38 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Country               object
#  2   VFN                   object
#  3   Mp                    object
#  4   Mh                    object
#  5   Man                   object
#  6   MMS                   float64
#  7   Tan                   object
#  8   T                     object
#  9   Va                    object
#  10  Ve                    object
#  11  Mk                    object
#  12  Cn                    object
#  13  Ct                    object
#  14  Cr                    object
#  15  r                     int64
#  16  m (kg)                float64
#  17  Mt                    float64
#  18  Enedc (g/km)          float64
#  19  Ewltp (g/km)          float64
#  20  W (mm)                float64
#  21  At1 (mm)              float64
# ...

# %%
data.describe()
# Out:
#                  ID  MMS          r        m (kg)            Mt  Enedc (g/km)  \
# count  9.479544e+06  0.0  9479544.0  9.479417e+06  9.310777e+06  1.624377e+06
# mean   7.987085e+07  NaN        1.0  1.526647e+03  1.642249e+03  7.675505e+00
# std    3.959084e+06  NaN        0.0  3.522932e+02  3.688740e+02  1.503173e+01
# min    1.000000e+00  NaN        1.0  5.700000e+02  6.150000e+02  0.000000e+00
# 25%    7.725408e+07  NaN        1.0  1.262000e+03  1.371000e+03  0.000000e+00
# 50%    8.004128e+07  NaN        1.0  1.455000e+03  1.572000e+03  0.000000e+00
# 75%    8.328886e+07  NaN        1.0  1.735000e+03  1.859000e+03  0.000000e+00
# max    8.600022e+07  NaN        1.0  4.600000e+03  4.711000e+03  4.900000e+01
#
#        Ewltp (g/km)        W (mm)      At1 (mm)      At2 (mm)      ec (cm3)  \
# count  9.471133e+06  9.437945e+06  9.328089e+06  9.301499e+06  8.201687e+06
# mean   1.082588e+02  2.670078e+03  1.554120e+03  1.555568e+03  1.544103e+03
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Country', 'VFN', 'Mp', 'Mh', 'Man', 'MMS', 'Tan', 'T', 'Va',
#        'Ve', 'Mk', 'Cn', 'Ct', 'Cr', 'r', 'm (kg)', 'Mt', 'Enedc (g/km)',
#        'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'At2 (mm)', 'Ft', 'Fm',
#        'ec (cm3)', 'ep (KW)', 'z (Wh/km)', 'IT', 'Ernedc (g/km)',
#        'Erwltp (g/km)', 'De', 'Vf', 'Status', 'year', 'Date of registration',
#        'Fuel consumption ', 'Electric range (km)'],
#       dtype='object')

# %%
data.shape
# Out:
# (9479544, 38)

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data['Ft'].unique()
# Out:
# array(['petrol', 'electric', 'diesel', 'lpg', 'petrol/electric',
#        'diesel/electric', 'ng', 'e85', 'hydrogen', 'unknown'],
#       dtype=object)

# %%
#Suppression electric, hydrogen et unknown
data = data.loc[(data['Ft']=='petrol') | (data['Ft']=='diesel') | (data['Ft']=='lpg') | (data['Ft']=='petrol/electric') | (data['Ft']=='diesel/electric') | (data['Ft']=='ng') | (data['Ft']=='e85')]

# %%
data['Ft'].unique()
# Out:
# array(['petrol', 'diesel', 'lpg', 'petrol/electric', 'diesel/electric',
#        'ng', 'e85'], dtype=object)

# %%
data['Country'].unique()
# Out:
# array(['FR', 'IE', 'SE', 'GR', 'NL', 'DE', 'PT', 'IS', 'MT', 'PL', 'FI',
#        'LT', 'CZ', 'EE', 'LV', 'LU', 'IT', 'RO', 'HU', 'NO', 'SI', 'ES',
#        'AT', 'BE', 'SK', 'BG', 'HR', 'CY', 'DK'], dtype=object)

# %%
data =  data.loc[(data['Country']=='FR') | (data['Country']=='DE')]

# %%
data['Country'].unique()
# Out:
# array(['FR', 'DE'], dtype=object)

# %%
data.shape
#(3528584, 38)
# Out:
# (3528584, 38)

# %%
to_drop=['MMS', 'Ernedc (g/km)', 'De', 'Vf', 'Enedc (g/km)', 'year', 'r', 'Man']
data = data.drop(to_drop, axis=1)

# %%
to_drop=['Date of registration', 'Status', 'T', 'Va', 'Ve', 'VFN']
data = data.drop(to_drop, axis=1)

# %%
to_drop=['ID', 'Electric range (km)']
data = data.drop(to_drop, axis=1)

# %%
data = data.drop('z (Wh/km)', axis=1)

# %%
data = data.drop('Tan', axis=1)

# %%
data = data.drop('Mp', axis=1)

# %%
import numpy as np
from scipy.stats import pearsonr

# Calcul du coefficient de corrélation de Pearson et de la p-value
correlation_coefficient, p_value = pearsonr(data['m (kg)'], data['Mt'])

print("Coefficient de corrélation de Pearson:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# Coefficient de corrélation de Pearson: nan
# P-value: nan

# %%
correlation_coefficient, p_value = pearsonr(data['m (kg)'], data['Ewltp (g/km)'])

print("Coefficient de corrélation de Pearson:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# Coefficient de corrélation de Pearson: 0.01573468935526814
# P-value: 5.078674681167959e-192

# %%
correlation_coefficient, p_value = pearsonr(data['Mt'], data['Ewltp (g/km)'])

print("Coefficient de corrélation de Pearson:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# Coefficient de corrélation de Pearson: 0.04879396917528243
# P-value: 0.0

# %%
correlation_coefficient, p_value = pearsonr(data['At1 (mm)'], data['At2 (mm)'])

print("Coefficient de corrélation de Pearson:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# Coefficient de corrélation de Pearson: 0.963175728736114
# P-value: 0.0

# %%
correlation_coefficient, p_value = pearsonr(data['At1 (mm)'], data['Ewltp (g/km)'])

print("Coefficient de corrélation de Pearson:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# Coefficient de corrélation de Pearson: 0.14135203953531392
# P-value: 0.0

# %%
correlation_coefficient, p_value = pearsonr(data['At2 (mm)'], data['Ewltp (g/km)'])

print("Coefficient de corrélation de Pearson:", correlation_coefficient)
print("P-value:", p_value)
# Out:
# Coefficient de corrélation de Pearson: 0.1405639702690893
# P-value: 0.0

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Création du tableau de contingence
contingency_table = pd.crosstab(data['Ft'], data['Fm'])

# Test du chi-deux
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 8317857.136824946
# P-value : 0.0

# %%
contingency_table = pd.crosstab(data['Ft'], data['Ewltp (g/km)'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 5229750.706044124
# P-value : 0.0

# %%
contingency_table = pd.crosstab(data['Fm'], data['Ewltp (g/km)'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 4737290.74189703
# P-value : 0.0

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Création du modèle ANOVA
model = ols('Ft ~ Ewltp (g/km)', data=data).fit()

# Résumé du modèle ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\patsy\compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\patsy\eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'Ewltp' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[46], line 5
#       2 from statsmodels.formula.api import ols
# ...

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Création du modèle ANOVA
model = ols('Fm ~ Ewltp (g/km)', data=data).fit()

# Résumé du modèle ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Création du tableau de contingence
contingency_table = pd.crosstab(data['Ct'], data['Cr'])

# Test du chi-deux
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 3525464.338075409
# P-value : 0.0

# %%
import statsmodels.api 
result = statsmodels.formula.api.ols('Ewltp (g/km) ~ Ct', data=data).fit()
table = statsmodels.api.stats.anova_lm(result)
display(table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\patsy\compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\patsy\eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'Ewltp' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[50], line 2
#       1 import statsmodels.api
# ...

# %%
import statsmodels.api 
result = statsmodels.formula.api.ols('Ewltp (g/km) ~ Cr', data=data).fit()
table = statsmodels.api.stats.anova_lm(result)
display(table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\patsy\compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\patsy\eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'Ewltp' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Cell In[51], line 2
#       1 import statsmodels.api
# ...

# %%
contingency_table = pd.crosstab(data['Ct'], data['Ewltp (g/km)'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 1009019.9127604889
# P-value : 0.0

# %%
contingency_table = pd.crosstab(data['Cr'], data['Ewltp (g/km)'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 979302.3348195866
# P-value : 0.0

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Création du tableau de contingence
contingency_table = pd.crosstab(data['Mk'], data['Mh'])

# Test du chi-deux
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 171108695.57969993
# P-value : 0.0

# %%
contingency_table = pd.crosstab(data['Mk'], data['Ewltp (g/km)'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 38820230.53531816
# P-value : 0.0

# %%
contingency_table = pd.crosstab(data['Mh'], data['Ewltp (g/km)'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("Valeur de chi2 :", chi2)
print("P-value :", p_value)
# Out:
# Valeur de chi2 : 40090668.0306883
# P-value : 0.0

# %%
to_drop=['m (kg)', 'At2 (mm)', 'Fm']
data = data.drop(to_drop, axis=1)

# %%
to_drop=['Cn', 'Cr']
data = data.drop(to_drop, axis=1)

# %%
data = data.drop('Mk', axis=1)

# %%
data.shape
# Out:
# (3528584, 13)

# %%
data.columns
# Out:
# Index(['Country', 'Mh', 'Ct', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'Ft',
#        'ec (cm3)', 'ep (KW)', 'IT', 'Erwltp (g/km)', 'Fuel consumption '],
#       dtype='object')

# %%
data.isna().sum() / len(data)
# Out:
# Country              0.000000e+00
# Mh                   0.000000e+00
# Ct                   2.833998e-07
# Mt                   3.791606e-03
# Ewltp (g/km)         1.776067e-03
# W (mm)               3.666343e-03
# At1 (mm)             3.682497e-03
# Ft                   0.000000e+00
# ec (cm3)             1.983799e-06
# ep (KW)              8.501994e-07
# IT                   2.433747e-01
# Erwltp (g/km)        2.433741e-01
# Fuel consumption     6.448479e-03
# dtype: float64

# %%
data.isna().sum()
# Out:
# Country                   0
# Mp                   150994
# Mh                        0
# Tan                   14297
# Mk                      262
# Cn                      131
# Ct                        1
# Cr                        7
# m (kg)                    1
# Mt                    13379
# Ewltp (g/km)           6267
# W (mm)                12937
# At1 (mm)              12994
# At2 (mm)              17367
# Ft                        0
# Fm                        0
# ec (cm3)                  7
# ep (KW)                   3
# IT                   858768
# Erwltp (g/km)        858766
# Fuel consumption      22754
# dtype: int64

# %%
display(data)
# Out:
#         Country                         Mp                          Mh  \
# 0            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# 1            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# 2            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# 3            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# 4            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# ...         ...                        ...                         ...
# 9479351      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
# 9479352      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
# 9479353      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
# 9479354      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
# 9479355      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
#
#                         Tan                              Mk  \
# ...

# %%
data_2 = data

# %%
data_2.shape
# Out:
# (3528584, 13)

# %%
#data_2.to_csv("C:\Users\lydia\Documents\Datascientest\Projet fil rouge\data_2.csv")
data_2.to_csv("C:/Users/frobi/OneDrive/Documents/GitHub/dec23_cds_co2/data/processed/data_2.csv")

# %%
import os

# %%
chemin_documents = os.path.expanduser('C:/Users/frobi/OneDrive/Documents/GitHub/dec23_cds_co2/data/processed/')

# %%
chemin_fichier_csv = os.path.join(chemin_documents, 'data_2.csv')

# %%
data_2
# Out:
#         Country                          Mh  Ct      Mt  Ewltp (g/km)  W (mm)  \
# 6            FR                     RENAULT  M1  1071.0         117.0  2492.0
# 7            FR                     RENAULT  M1  1077.0         117.0  2492.0
# 8            FR                     RENAULT  M1  1075.0         117.0  2492.0
# 9            FR                     RENAULT  M1  1073.0         117.0  2492.0
# 10           FR                     RENAULT  M1  1077.0         117.0  2492.0
# ...         ...                         ...  ..     ...           ...     ...
# 9479351      DE  MITSUBISHI MOTORS THAILAND  M1  1062.0         113.0  2450.0
# 9479352      DE  MITSUBISHI MOTORS THAILAND  M1  1091.0         125.0  2450.0
# 9479353      DE  MITSUBISHI MOTORS THAILAND  M1  1091.0         125.0  2450.0
# 9479354      DE  MITSUBISHI MOTORS THAILAND  M1  1091.0         125.0  2450.0
# 9479355      DE  MITSUBISHI MOTORS THAILAND  M1  1091.0         125.0  2450.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Q1 = data_2['m (kg)'].quantile(0.25)
Q3 = data_2['m (kg)'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['m (kg)'] < seuil_inf) | (data_2['m (kg)'] > seuil_sup)]
display(outliers)
# Out:
#         Country             Mp                Mh                 Tan  \
# 60127        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60128        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60129        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60130        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60131        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# ...         ...            ...               ...                 ...
# 8553966      DE            NaN            AA-IVA                 NaN
# 8553967      DE            NaN            AA-IVA                 NaN
# 8553968      DE            NaN            AA-IVA                 NaN
# 8553969      DE            NaN            AA-IVA                 NaN
# 8553970      DE            NaN            AA-IVA                 NaN
#
#                     Mk                 Cn   Ct   Cr  m (kg)      Mt  ...  \
# ...

# %%
Q1 = data_2['Mt'].quantile(0.25)
Q3 = data_2['Mt'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['Mt'] < seuil_inf) | (data_2['Mt'] > seuil_sup)]
display(outliers)
# Out:
#         Country             Mp                 Mh                  Tan  \
# 60127        FR  MERCEDES-BENZ   MERCEDES-BENZ AG   E1*2007/46*1885*17
# 60128        FR  MERCEDES-BENZ   MERCEDES-BENZ AG   E1*2007/46*1885*17
# 60129        FR  MERCEDES-BENZ   MERCEDES-BENZ AG   E1*2007/46*1885*17
# 60130        FR  MERCEDES-BENZ   MERCEDES-BENZ AG   E1*2007/46*1885*17
# 60131        FR  MERCEDES-BENZ   MERCEDES-BENZ AG   E1*2007/46*1885*17
# ...         ...            ...                ...                  ...
# 8505404      DE     STELLANTIS  STELLANTIS EUROPE  e3*2001/116*0232*34
# 8505406      DE     STELLANTIS  STELLANTIS EUROPE  e3*2001/116*0232*34
# 8505409      DE     STELLANTIS  STELLANTIS EUROPE  e3*2001/116*0232*35
# 8505411      DE     STELLANTIS  STELLANTIS EUROPE  e3*2001/116*0232*34
# 8505414      DE     STELLANTIS  STELLANTIS EUROPE   e3*2007/46*0049*35
#
#                     Mk                 Cn   Ct   Cr  m (kg)      Mt  ...  \
# ...

# %%
Q1 = data_2['Ewltp (g/km)'].quantile(0.25)
Q3 = data_2['Ewltp (g/km)'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['Ewltp (g/km)'] < seuil_inf) | (data_2['Ewltp (g/km)'] > seuil_sup)]
display(outliers)
# Out:
#         Country                         Mp                             Mh  \
# 49000        FR              MERCEDES-BENZ               MERCEDES-BENZ AG
# 49001        FR              MERCEDES-BENZ               MERCEDES-BENZ AG
# 49002        FR              MERCEDES-BENZ               MERCEDES-BENZ AG
# 49003        FR              MERCEDES-BENZ               MERCEDES-BENZ AG
# 49004        FR              MERCEDES-BENZ               MERCEDES-BENZ AG
# ...         ...                        ...                            ...
# 9479339      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
# 9479340      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
# 9479341      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
# 9479342      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
# 9479343      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS CORPORATION
#
#                          Tan                             Mk  \
# ...

# %%
Q1 = data_2['W (mm)'].quantile(0.25)
Q3 = data_2['W (mm)'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['W (mm)'] < seuil_inf) | (data_2['W (mm)'] > seuil_sup)]
display(outliers)
# Out:
#         Country             Mp                Mh                 Tan  \
# 60126        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60127        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60128        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60129        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60130        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2007/46*1885*17
# ...         ...            ...               ...                 ...
# 8553954      DE            NaN          MASERATI  e3*2007/46*0224*26
# 8553955      DE            NaN          MASERATI  e3*2007/46*0224*26
# 8553956      DE            NaN          MASERATI  e3*2007/46*0224*26
# 8553957      DE     VOLKSWAGEN       LAMBORGHINI  e3*2007/46*0616*02
# 8553959      DE            NaN            AA-IVA                 NaN
#
#                     Mk                 Cn   Ct   Cr  m (kg)      Mt  ...  \
# ...

# %%
Q1 = data_2['At1 (mm)'].quantile(0.25)
Q3 = data_2['At1 (mm)'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['At1 (mm)'] < seuil_inf) | (data_2['At1 (mm)'] > seuil_sup)]
display(outliers)
# Out:
#         Country             Mp                Mh                  Tan  \
# 49967        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*42
# 49968        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*43
# 60126        FR  MERCEDES-BENZ  MERCEDES-BENZ AG   E1*2007/46*1885*17
# 60127        FR  MERCEDES-BENZ  MERCEDES-BENZ AG   E1*2007/46*1885*17
# 60128        FR  MERCEDES-BENZ  MERCEDES-BENZ AG   E1*2007/46*1885*17
# ...         ...            ...               ...                  ...
# 8552273      DE            NaN           FERRARI  e24*ks07/46*0077*13
# 8552274      DE            NaN           FERRARI  e24*ks07/46*0077*13
# 8552275      DE            NaN           FERRARI  e24*ks07/46*0077*13
# 8553957      DE     VOLKSWAGEN       LAMBORGHINI   e3*2007/46*0616*02
# 8553959      DE            NaN            AA-IVA                  NaN
#
#                     Mk                    Cn   Ct   Cr  m (kg)      Mt  ...  \
# ...

# %%
Q1 = data_2['At2 (mm)'].quantile(0.25)
Q3 = data_2['At2 (mm)'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['At2 (mm)'] < seuil_inf) | (data_2['At2 (mm)'] > seuil_sup)]
display(outliers)
# Out:
#         Country             Mp                 Mh                 Tan  \
# 60126        FR  MERCEDES-BENZ   MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60127        FR  MERCEDES-BENZ   MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60128        FR  MERCEDES-BENZ   MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60129        FR  MERCEDES-BENZ   MERCEDES-BENZ AG  E1*2007/46*1885*17
# 60130        FR  MERCEDES-BENZ   MERCEDES-BENZ AG  E1*2007/46*1885*17
# ...         ...            ...                ...                 ...
# 8526819      DE     STELLANTIS  STELLANTIS EUROPE  e3*2007/46*0064*64
# 8526820      DE     STELLANTIS  STELLANTIS EUROPE  e3*2007/46*0064*64
# 8527524      DE     STELLANTIS  STELLANTIS EUROPE  e3*2007/46*0064*64
# 8553957      DE     VOLKSWAGEN        LAMBORGHINI  e3*2007/46*0616*02
# 8553959      DE            NaN             AA-IVA                 NaN
#
#                     Mk                 Cn   Ct   Cr  m (kg)      Mt  ...  \
# ...

# %%
Q1 = data_2['ec (cm3)'].quantile(0.25)
Q3 = data_2['ec (cm3)'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['ec (cm3)'] < seuil_inf) | (data_2['ec (cm3)'] > seuil_sup)]
display(outliers)
# Out:
#         Country             Mp                Mh                  Tan  \
# 49967        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*42
# 49968        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*43
# 60137        FR  MERCEDES-BENZ  MERCEDES-BENZ AG   E1*2007/46*1885*17
# 60163        FR  MERCEDES-BENZ  MERCEDES-BENZ AG   E1*2007/46*1885*17
# 60164        FR  MERCEDES-BENZ  MERCEDES-BENZ AG   E1*2007/46*1885*17
# ...         ...            ...               ...                  ...
# 8558961      DE            NaN           FERRARI   e3*2007/46*0040*24
# 8558962      DE            NaN           FERRARI   e3*2007/46*0040*24
# 8558963      DE            NaN           FERRARI   e3*2007/46*0040*24
# 8558964      DE            NaN           FERRARI   e3*2007/46*0040*24
# 8558965      DE            NaN           FERRARI   e3*2007/46*0040*24
#
#                     Mk                         Cn   Ct   Cr  m (kg)      Mt  \
# ...

# %%
Q1 = data_2['ep (KW)'].quantile(0.25)
Q3 = data_2['ep (KW)'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['ep (KW)'] < seuil_inf) | (data_2['ep (KW)'] > seuil_sup)]
display(outliers)
# Out:
#         Country             Mp                Mh                  Tan  \
# 49000        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*41
# 49001        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*43
# 49002        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*43
# 49003        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*43
# 49004        FR  MERCEDES-BENZ  MERCEDES-BENZ AG  E1*2001/116*0480*43
# ...         ...            ...               ...                  ...
# 8558961      DE            NaN           FERRARI   e3*2007/46*0040*24
# 8558962      DE            NaN           FERRARI   e3*2007/46*0040*24
# 8558963      DE            NaN           FERRARI   e3*2007/46*0040*24
# 8558964      DE            NaN           FERRARI   e3*2007/46*0040*24
# 8558965      DE            NaN           FERRARI   e3*2007/46*0040*24
#
#                     Mk                Cn  Ct  Cr  m (kg)      Mt  ...  W (mm)  \
# ...

# %%
Q1 = data_2['Erwltp (g/km)'].quantile(0.25)
Q3 = data_2['Erwltp (g/km)'].quantile(0.75)
IQR = Q3 - Q1
seuil_inf = Q1 - 1.5 * IQR
seuil_sup = Q3 + 1.5 * IQR
outliers = data_2[(data_2['Erwltp (g/km)'] < seuil_inf) | (data_2['Erwltp (g/km)'] > seuil_sup)]
display(outliers)
# Out:
# Empty DataFrame
# Columns: [Country, Mp, Mh, Tan, Mk, Cn, Ct, Cr, m (kg), Mt, Ewltp (g/km), W (mm), At1 (mm), At2 (mm), Ft, Fm, ec (cm3), ep (KW), IT, Erwltp (g/km), Fuel consumption ]
# Index: []
#
# [0 rows x 21 columns]

# %%
data_2['Erwltp (g/km)'] = data_2['Erwltp (g/km)'].fillna(data_2['Erwltp (g/km)'].mean())

# %%
data_2['Erwltp (g/km)'].isna().sum()
# Out:
# 0

# %%
data_2['Erwltp (g/km)'].mean()
# Out:
# 1.5309319361844131

# %%
data.isna().sum()
# Out:
# Country                   0
# Mp                   150994
# Mh                        0
# Tan                   14297
# Mk                      262
# Cn                      131
# Ct                        1
# Cr                        7
# m (kg)                    1
# Mt                    13379
# Ewltp (g/km)           6267
# W (mm)                12937
# At1 (mm)              12994
# At2 (mm)              17367
# Ft                        0
# Fm                        0
# ec (cm3)                  7
# ep (KW)                   3
# IT                   858768
# Erwltp (g/km)             0
# Fuel consumption      22754
# dtype: int64

# %%
median_colonne = data_2['m (kg)'].median()
data_2['m (kg)'].fillna(median_colonne, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\DEV\Anaconda\envs\dec23CDSCO2\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'm (kg)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 median_colonne = data_2['m (kg)'].median()
# ...

# %%
median_colonne = data_2['Mt'].median()
data_2['Mt'].fillna(median_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\3149131678.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['Mt'].fillna(median_colonne, inplace=True)

# %%
median_colonne = data_2['Ewltp (g/km)'].median()
data_2['Ewltp (g/km)'].fillna(median_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\2637062434.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['Ewltp (g/km)'].fillna(median_colonne, inplace=True)

# %%
median_colonne = data_2['W (mm)'].median()
data_2['W (mm)'].fillna(median_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\4169331954.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['W (mm)'].fillna(median_colonne, inplace=True)

# %%
median_colonne = data_2['At1 (mm)'].median()
data_2['At1 (mm)'].fillna(median_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\2637535900.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['At1 (mm)'].fillna(median_colonne, inplace=True)

# %%
median_colonne = data_2['At2 (mm)'].median()
data_2['At2 (mm)'].fillna(median_colonne, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\DEV\Anaconda\envs\dec23CDSCO2\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'At2 (mm)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 median_colonne = data_2['At2 (mm)'].median()
# ...

# %%
median_colonne = data_2['ec (cm3)'].median()
data_2['ec (cm3)'].fillna(median_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\2742650656.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['ec (cm3)'].fillna(median_colonne, inplace=True)

# %%
median_colonne = data_2['ep (KW)'].median()
data_2['ep (KW)'].fillna(median_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\423395109.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['ep (KW)'].fillna(median_colonne, inplace=True)

# %%
median_colonne = data_2['Fuel consumption '].median()
data_2['Fuel consumption '].fillna(median_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\560738483.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['Fuel consumption '].fillna(median_colonne, inplace=True)

# %%
data_2.isna().sum()
# Out:
# Country                   0
# Mh                        0
# Ct                        1
# Mt                        0
# Ewltp (g/km)              0
# W (mm)                    0
# At1 (mm)                  0
# Ft                        0
# ec (cm3)                  0
# ep (KW)                   0
# IT                   858768
# Erwltp (g/km)             0
# Fuel consumption          0
# dtype: int64

# %%
mode_colonne = data_2['Mk'].mode()[0] 
data_2['Mk'].fillna(mode_colonne, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\DEV\Anaconda\envs\dec23CDSCO2\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 mode_colonne = data_2['Mk'].mode()[0]
# ...

# %%
mode_colonne = data_2['Cn'].mode()[0] 
data_2['Cn'].fillna(mode_colonne, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\DEV\Anaconda\envs\dec23CDSCO2\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cn'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 mode_colonne = data_2['Cn'].mode()[0]
# ...

# %%
mode_colonne = data_2['Ct'].mode()[0] 
data_2['Ct'].fillna(mode_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\1276690101.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['Ct'].fillna(mode_colonne, inplace=True)

# %%
mode_colonne = data_2['Cr'].mode()[0] 
data_2['Cr'].fillna(mode_colonne, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\DEV\Anaconda\envs\dec23CDSCO2\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cr'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 mode_colonne = data_2['Cr'].mode()[0]
# ...

# %%
mode_colonne = data_2['IT'].mode()[0] 
data_2['IT'].fillna(mode_colonne, inplace=True)
# Out:
# C:\Users\frobi\AppData\Local\Temp\ipykernel_33268\1080102662.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_2['IT'].fillna(mode_colonne, inplace=True)

# %%
data.isna().sum()
# Out:
# Country              0
# Mh                   0
# Ct                   0
# Mt                   0
# Ewltp (g/km)         0
# W (mm)               0
# At1 (mm)             0
# Ft                   0
# ec (cm3)             0
# ep (KW)              0
# IT                   0
# Erwltp (g/km)        0
# Fuel consumption     0
# dtype: int64

# %%
data_2.isna().sum()
# Out:
# Country              0
# Mh                   0
# Ct                   0
# Mt                   0
# Ewltp (g/km)         0
# W (mm)               0
# At1 (mm)             0
# Ft                   0
# ec (cm3)             0
# ep (KW)              0
# IT                   0
# Erwltp (g/km)        0
# Fuel consumption     0
# dtype: int64

# %%
display(data_2)
# Out:
#         Country                          Mh  Ct      Mt  Ewltp (g/km)  W (mm)  \
# 6            FR                     RENAULT  M1  1071.0         117.0  2492.0
# 7            FR                     RENAULT  M1  1077.0         117.0  2492.0
# 8            FR                     RENAULT  M1  1075.0         117.0  2492.0
# 9            FR                     RENAULT  M1  1073.0         117.0  2492.0
# 10           FR                     RENAULT  M1  1077.0         117.0  2492.0
# ...         ...                         ...  ..     ...           ...     ...
# 9479351      DE  MITSUBISHI MOTORS THAILAND  M1  1062.0         113.0  2450.0
# 9479352      DE  MITSUBISHI MOTORS THAILAND  M1  1091.0         125.0  2450.0
# 9479353      DE  MITSUBISHI MOTORS THAILAND  M1  1091.0         125.0  2450.0
# 9479354      DE  MITSUBISHI MOTORS THAILAND  M1  1091.0         125.0  2450.0
# 9479355      DE  MITSUBISHI MOTORS THAILAND  M1  1091.0         125.0  2450.0
#
# ...

# %%
data_2['Country'].value_counts()
# Out:
# Country
# DE    2100267
# FR    1428317
# Name: count, dtype: int64

# %%
data_2['Mh'].value_counts()
# Out:
# Mh
# VOLKSWAGEN              492019
# STELLANTIS AUTO         356037
# RENAULT                 319626
# BMW AG                  270357
# MERCEDES-BENZ AG        256294
#                          ...
# UNKNOWN                      4
# DR AUTOMOBILES               4
# BUGATTI                      2
# FORD MOTOR AUSTRALIA         1
# HENAN SUDA                   1
# Name: count, Length: 70, dtype: int64

# %%
data_2['Mk'].value_counts()
# Out:
# Mk
# VOLKSWAGEN. VW              405503
# RENAULT                     267912
# PEUGEOT                     267651
# MERCEDES-BENZ               257912
# BMW                         230120
#                              ...
# MERCEDES BENZQ                   1
# XINGYUE                          1
# SUDA                             1
# GREAT WALL MOTOR COMPANY         1
# LISTERBELL                       1
# Name: count, Length: 128, dtype: int64

# %%
data_2['Cn'].value_counts()
# Out:
# Cn
# GOLF                90807
# SANDERO             85952
# T-ROC               76701
# C3                  76698
# TIGUAN              71817
#                     ...
# NX4                     1
# X5 XDRIVE 25D           1
# AUDI A3 40 TFSIE        1
# TIPO                    1
# CITROEN                 1
# Name: count, Length: 1727, dtype: int64

# %%
data_2['Ct'].value_counts()
# Out:
# Ct
# M1     3354938
# M1G     173622
# N1          22
# N1G          2
# Name: count, dtype: int64

# %%
data_2['Cr'].value_counts()
# Out:
# Cr
# M1     3355082
# M1G     173502
# Name: count, dtype: int64

# %%
data_2['Ft'].value_counts()
# Out:
# Ft
# petrol             2085499
# diesel              853226
# petrol/electric     466885
# lpg                  61883
# e85                  35908
# diesel/electric      23209
# ng                    1974
# Name: count, dtype: int64

# %%
data_2['IT'].value_counts()
# Out:
# IT
# e2 28 29      1208755
# e1 29          263099
# e9 29 37       227724
# e13 29         157252
# e2 29 37       154764
#                ...
# e13 29  37          4
# e3  29              2
# e13 32  37          2
# e8 29 28            1
# e13  37             1
# Name: count, Length: 93, dtype: int64

# %%
data_2['Mp'].unique()
# Out:
# array(['RENAULT-NISSAN-MITSUBISHI', 'MERCEDES-BENZ', 'VOLKSWAGEN', nan,
#        'BMW', 'STELLANTIS', 'MAZDA-SUBARU-SUZUKI-TOYOTA', 'KIA', 'FORD',
#        'HYUNDAI MOTOR EUROPE', 'TESLA-HONDA-JLR'], dtype=object)

# %%
data_2['Mh'].unique()
# Out:
# array(['RENAULT', 'MERCEDES-BENZ AG', 'AUDI AG', 'ALPINA', 'DUPLICATE',
#        'SEAT', 'AA-IVA', 'BMW AG', 'UNKNOWN', 'VOLKSWAGEN',
#        'AUTOMOBILES PEUGEOT', 'STELLANTIS AUTO', 'OUT OF SCOPE', 'DACIA',
#        'SKODA', 'AUDI HUNGARIA', 'MAGYAR SUZUKI', 'KIA SLOVAKIA',
#        'CHRYSLER', 'MAZDA', 'TOYOTA', 'DONKERVOORT',
#        'AUTOMOBILES CITROEN', 'MERCEDES AMG', 'PORSCHE', 'AUDI SPORT',
#        'FORD WERKE GMBH', 'RENAULT TRUCKS', 'ALPINE', 'SECMA',
#        'NISSAN AUTOMOTIVE EUROPE', 'OPEL AUTOMOBILE', 'BUGATTI',
#        'HYUNDAI ASSAN', 'MORGAN', 'HENAN SUDA',
#        'JAGUAR LAND ROVER LIMITED', 'MCLAREN', 'ROLLS-ROYCE', 'BENTLEY',
#        'LOTUS', 'ASTON MARTIN', 'CATERHAM', 'HONDA MOTOR CO',
#        'SUZUKI MOTOR CORPORATION', 'TOYOTA MOTOR CORPORATION',
#        'SAIC MOTOR CORPORATION', 'VOLVO', 'DFSK',
#        'MITSUBISHI MOTORS THAILAND', 'KIA', 'HYUNDAI',
#        'FORD MOTOR AUSTRALIA', 'FORD MOTOR COMPANY', 'SUBARU',
# ...

# %%
data_2['Mk'].unique()
# Out:
# array(['RENAULT', 'DACIA', 'MERCEDES-BENZ', 'AUDI', 'MERCEDES BENZ',
#        'ALPINA', 'SEAT', 'BMW', 'BMW M', 'VOLKSWAGEN. VW', 'KLASSEN',
#        'AUDI AG', 'CUPRA', 'OPEL', 'PEUGEOT', 'FIAT', 'MERCEDES-AMG',
#        'MERCEDES AMG', 'MERCEDES BENZQ', 'SKODA', 'SUZUKI', 'KIA', 'JEEP',
#        'MAZDA', 'HONDA', 'HYUNDAI', 'TOYOTA', 'VOLKSWAGEN', 'DONKERVOORT',
#        'CITROEN', 'CASELANI', 'MINI', 'PORSCHE', 'AUDI SPORT', 'FORD',
#        'INEOS AUTOMOTIVE GMBH', 'BUSCONCEPT', 'RENAULT SPORT',
#        'FORD-CNG-TECHNIK', 'RANDGER', 'ALPINE', 'SECMA', 'NISSAN',
#        'DS AUTOMOBILES', 'DS', 'BUGATTI', 'TATA', 'MORGAN', 'SUDA',
#        'WESTFIELD(GB)', 'JAGUAR', 'LAND ROVER', 'MCLAREN', 'ROLLS-ROYCE',
#        'BENTLEY', 'LOTUS', 'ASTON MARTIN', 'CATERHAM CARS LTD',
#        'CATERHAM CARS LTD.', 'INFINITI', 'MG. ROEWE', 'VOLVO',
#        'DFSK. SERES. SOKON', 'DFSK. SOKON', 'DFSK', 'DXK6470AS2F',
#        'MITSUBISHI MOTORS (THAILAND)', 'ISUZU', 'MITSUBISHI', 'SAIC MG',
# ...

# %%
data_2.loc[data_2['Mk'] == 'RENAULT', 'Mh'].fillna('RENAULT', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'RENAULT SPORT', 'Mh'].fillna('RENAULT', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'NISSAN', 'Mh'].fillna('RENAULT', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MITSUBISHI MOTORS (THAILAND)', 'Mh'].fillna('RENAULT', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MITSUBISHI', 'Mh'].fillna('RENAULT', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MITSUBISHI MOTORS CORPORATION', 'Mh'].fillna('RENAULT', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MITSUBISHI MOTORS (THAILAND) C', 'Mh'].fillna('RENAULT', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MERCEDES-BENZ', 'Mh'].fillna('MERCEDES-BENZ AG', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MERCEDES BENZ', 'Mh'].fillna('MERCEDES-BENZ AG', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MERCEDES-AMG', 'Mh'].fillna('MERCEDES-BENZ AG', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MERCEDES AMG', 'Mh'].fillna('MERCEDES-BENZ AG', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'MERCEDES BENZQ', 'Mh'].fillna('MERCEDES-BENZ AG', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'BMW', 'Mp'].fillna('BMW', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'BMW M', 'Mp'].fillna('BMW', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'BMW BRILLIANCE (RC)', 'Mp'].fillna('BMW', inplace=True)

# %%
data_2.loc[data_2['Mk'] == 'AUDI', 'Mp'].fillna('AUDI', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'VOLKSWAGEN', 'Mp'].fillna('VOLKSWAGEN', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'STELLANTIS AUTO', 'Mp'].fillna('STELLANTIS', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'STELLANTIS EUROPE', 'Mp'].fillna('STELLANTIS', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'MAGYAR SUZUKI', 'Mp'].fillna('MAZDA-SUBARU-SUZUKI-TOYOTA', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'MAZDA', 'Mp'].fillna('MAZDA-SUBARU-SUZUKI-TOYOTA', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'TOYOTA', 'Mp'].fillna('MAZDA-SUBARU-SUZUKI-TOYOTA', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'SUZUKI MOTOR CORPORATION', 'Mp'].fillna('MAZDA-SUBARU-SUZUKI-TOYOTA', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'MAZDA EUROPE', 'Mp'].fillna('MAZDA-SUBARU-SUZUKI-TOYOTA', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'MAZDA EUROPE', 'Mp'].fillna('MAZDA-SUBARU-SUZUKI-TOYOTA', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'KIA SLOVAKIA', 'Mp'].fillna('KIA', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'KIA', 'Mp'].fillna('KIA', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'FORD WERKE GMBH', 'Mp'].fillna('FORD', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'FORD MOTOR AUSTRALIA', 'Mp'].fillna('FORD', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'FORD MOTOR COMPANY', 'Mp'].fillna('FORD', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'HYUNDAI ASSAN', 'Mp'].fillna('HYUNDAI MOTOR EUROPE', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'HYUNDAI', 'Mp'].fillna('HYUNDAI MOTOR EUROPE', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'HYUNDAI CZECH', 'Mp'].fillna('HYUNDAI MOTOR EUROPE', inplace=True)

# %%
data_2.loc[data_2['Mh'] == 'HONDA MOTOR CO', 'Mp'].fillna('TESLA-HONDA-JLR', inplace=True)

# %%
data.isna().sum()
# Out:
# Country                   0
# Mp                   150994
# Mh                        0
# Tan                       0
# Mk                        0
# Cn                        0
# Ct                        0
# Cr                        0
# m (kg)                    0
# Mt                        0
# Ewltp (g/km)              0
# W (mm)                    0
# At1 (mm)                  0
# At2 (mm)                  0
# Ft                        0
# Fm                        0
# ec (cm3)                  0
# ep (KW)                   0
# IT                        0
# Erwltp (g/km)             0
# Fuel consumption          0
# dtype: int64

# %%
data_2.shape
# Out:
# (3528584, 13)

# %%
data_2_cat = data_2.drop(['r', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'ec (cm3)', 'ep (KW)',
                           'Erwltp (g/km)', 'Fuel consumption '], axis=1)
data_2_quant = data_2[['r', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'ec (cm3)', 'ep (KW)',
                      'Erwltp (g/km)', 'Fuel consumption ']]

# %%
display(data_2)
# Out:
#         Country                         Mp                          Mh  \
# 0            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# 1            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# 2            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# 3            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# 4            FR  RENAULT-NISSAN-MITSUBISHI                     RENAULT
# ...         ...                        ...                         ...
# 9479351      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
# 9479352      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
# 9479353      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
# 9479354      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
# 9479355      DE  RENAULT-NISSAN-MITSUBISHI  MITSUBISHI MOTORS THAILAND
#
#                         Tan                              Mk  \
# ...

# %%
from sklearn.impute import KNNImputer
KNNi = KNNImputer(n_neighbors=2)
KNNi.fit_transform(data_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1804\2762033612.py in ?()
#       1 from sklearn.impute import KNNImputer
#       2
#       3
#       4 KNNi = KNNImputer(n_neighbors=2)
# ----> 5 KNNi.fit_transform(data_2)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     874         # non-optimized default implementation; override when a better
#     875         # method is possible for a given clustering algorithm
# ...

# %%
df_Categorielle = df.drop(['r', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'ec (cm3)', 'ep (KW)',
                           'Erwltp (g/km)', 'Fuel consumption '], axis=1)
df_quantitative = df[['r', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'ec (cm3)', 'ep (KW)',
                      'Erwltp (g/km)', 'Fuel consumption ']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 df_Categorielle = df.drop(['r', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'ec (cm3)', 'ep (KW)',
#       2                            'Erwltp (g/km)', 'Fuel consumption '], axis=1)
#       3 df_quantitative = df[['r', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'ec (cm3)', 'ep (KW)',
#       4                       'Erwltp (g/km)', 'Fuel consumption ']]
#
# NameError: name 'df' is not defined

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data_2['Ft'] = le.fit_transform(data_2['Ft'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data_2['Mh'] = le.fit_transform(data_2['Mh'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data_2['IT'] = le.fit_transform(data_2['IT'])

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Création de l'encodeur OneHotEncoder
encoder = OneHotEncoder(sparse=False)

# Ajustement et transformation des données
encoded_data = encoder.fit_transform(data_2[['Ct']])

# Création d'un DataFrame pour les données encodées
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(['Ct']))

# Concaténation du DataFrame encodé avec le DataFrame original
data_2_encoded = pd.concat([data_2.reset_index(drop=True), encoded_df], axis=1)

# Affichage des résultats
print("DataFrame original :")
display(data_2)
print("\nDataFrame encodé :")
display(data_2_encoded)
# Out:
# C:\Users\lydia\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# DataFrame original :
#         Country  Mh  Ct      Mt  Ewltp (g/km)  W (mm)  At1 (mm)  Ft  ec (cm3)  \
# 0            FR  54  M1  1076.0         117.0  2492.0    1455.0   5     999.0
# 1            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 2            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 3            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 4            FR  54  M1  1071.0         117.0  2492.0    1455.0   5     999.0
# ...         ...  ..  ..     ...           ...     ...       ...  ..       ...
# 9479351      DE  48  M1  1062.0         113.0  2450.0    1430.0   5    1193.0
# ...

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Création de l'encodeur OneHotEncoder
encoder = OneHotEncoder(sparse=False)

# Ajustement et transformation des données
encoded_data = encoder.fit_transform(data_2[['Country']])

# Création d'un DataFrame pour les données encodées
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(['Country']))

# Concaténation du DataFrame encodé avec le DataFrame original
data_2_2_encoded = pd.concat([data_2.reset_index(drop=True), encoded_df], axis=1)

# Affichage des résultats
print("DataFrame original :")
display(data_2)
print("\nDataFrame encodé :")
display(data_2_2_encoded)
# Out:
# C:\Users\lydia\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# DataFrame original :
#         Country  Mh  Ct      Mt  Ewltp (g/km)  W (mm)  At1 (mm)  Ft  ec (cm3)  \
# 0            FR  54  M1  1076.0         117.0  2492.0    1455.0   5     999.0
# 1            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 2            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 3            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 4            FR  54  M1  1071.0         117.0  2492.0    1455.0   5     999.0
# ...         ...  ..  ..     ...           ...     ...       ...  ..       ...
# 9479351      DE  48  M1  1062.0         113.0  2450.0    1430.0   5    1193.0
# ...

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# Création de l'encodeur OneHotEncoder
encoder = OneHotEncoder(sparse=False)

# Ajustement et transformation des données pour la variable 'Ct'
encoded_data_ct = encoder.fit_transform(data_2[['Ct']])
encoded_df_ct = pd.DataFrame(encoded_data_ct, columns=encoder.get_feature_names_out(['Ct']))

# Ajustement et transformation des données pour la variable 'Country'
encoded_data_country = encoder.fit_transform(data_2[['Country']])
encoded_df_country = pd.DataFrame(encoded_data_country, columns=encoder.get_feature_names_out(['Country']))

# Concaténation des DataFrames encodés
data_2_encoded = pd.concat([data_2.reset_index(drop=True), encoded_df_ct, encoded_df_country], axis=1)

# Affichage des résultats
print("DataFrame original :")
print(data_2)
print("\nDataFrame encodé :")
print(data_2_encoded)
# Out:
# C:\Users\lydia\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\lydia\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# DataFrame original :
#         Country  Mh  Ct      Mt  Ewltp (g/km)  W (mm)  At1 (mm)  Ft  ec (cm3)  \
# 0            FR  54  M1  1076.0         117.0  2492.0    1455.0   5     999.0
# 1            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 2            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 3            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# ...

# %%
data_2.shape
# Out:
# (3528584, 13)

# %%
data_2_encoded.shape
# Out:
# (3528584, 19)

# %%
# Suppression des doublons
data_2_encoded_unique = data_2_encoded.drop_duplicates()

# Affichage du DataFrame sans doublons
print("DataFrame sans doublons :")
print(data_2_encoded_unique)
# Out:
# DataFrame sans doublons :
#         Country  Mh  Ct      Mt  Ewltp (g/km)  W (mm)  At1 (mm)  Ft  ec (cm3)  \
# 0            FR  54  M1  1076.0         117.0  2492.0    1455.0   5     999.0
# 1            FR  54  M1  1077.0         117.0  2492.0    1455.0   5     999.0
# 4            FR  54  M1  1071.0         117.0  2492.0    1455.0   5     999.0
# 7            FR  54  M1  1080.0         117.0  2492.0    1455.0   5     999.0
# 13           FR  54  M1  1073.0         117.0  2492.0    1455.0   5     999.0
# ...         ...  ..  ..     ...           ...     ...       ...  ..       ...
# 3528118      DE  62  M1  1608.0         132.0  2570.0    1545.0   0    1598.0
# 3528119      DE  62  M1  1644.0         132.0  2570.0    1545.0   0    1598.0
# 3528120      DE  22  M1  1877.0         256.0  2670.0    1633.0   5    3855.0
# 3528271      DE  22  M1  1846.0         385.0  2720.0    1672.0   5    6496.0
# 3528314      DE  22  M1  1931.0         366.0  2720.0    1672.0   5    6496.0
#
# ...

# %%
data_2_encoded_unique.shape
# Out:
# (457140, 19)

# %%
to_drop=['Country', 'Ct']
data_2_encoded = data_2_encoded.drop(to_drop, axis=1)

# %%
display(data_2_encoded)
# Out:
#          Mh      Mt  Ewltp (g/km)  W (mm)  At1 (mm)  Ft  ec (cm3)  ep (KW)  \
# 0        54  1076.0         117.0  2492.0    1455.0   5     999.0     48.0
# 1        54  1077.0         117.0  2492.0    1455.0   5     999.0     48.0
# 2        54  1077.0         117.0  2492.0    1455.0   5     999.0     48.0
# 3        54  1077.0         117.0  2492.0    1455.0   5     999.0     48.0
# 4        54  1071.0         117.0  2492.0    1455.0   5     999.0     48.0
# ...      ..     ...           ...     ...       ...  ..       ...      ...
# 3528579  48  1062.0         113.0  2450.0    1430.0   5    1193.0     52.0
# 3528580  48  1091.0         125.0  2450.0    1430.0   5    1193.0     52.0
# 3528581  48  1091.0         125.0  2450.0    1430.0   5    1193.0     52.0
# 3528582  48  1091.0         125.0  2450.0    1430.0   5    1193.0     52.0
# 3528583  48  1091.0         125.0  2450.0    1430.0   5    1193.0     52.0
#
# ...

# %%
target = data_2_encoded['Ewltp (g/km)']
feats = data_2_encoded.drop('Ewltp (g/km)', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(feats, target, test_size=0.20)

# %%
data_2_encoded.columns
# Out:
# Index(['Mh', 'Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'Ft', 'ec (cm3)',
#        'ep (KW)', 'IT', 'Erwltp (g/km)', 'Fuel consumption ', 'Ct_M1',
#        'Ct_M1G', 'Ct_N1', 'Ct_N1G', 'Country_DE', 'Country_FR'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
cols_num = ['Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'ec (cm3)', 'ep (KW)', 'Erwltp (g/km)', 'Fuel consumption ']

sc = StandardScaler()
X_train[cols_num] = sc.fit_transform(X_train[cols_num])
X_test[cols_num] = sc.transform(X_test[cols_num])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[110], line 5
#       2 cols_num = ['Mt', 'Ewltp (g/km)', 'W (mm)', 'At1 (mm)', 'ec (cm3)', 'ep (KW)', 'Erwltp (g/km)', 'Fuel consumption ']
#       4 sc = StandardScaler()
# ----> 5 X_train[cols_num] = sc.fit_transform(X_train[cols_num])
#       6 X_test[cols_num] = sc.transform(X_test[cols_num])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
# ...

# %%
data_3 = data_2_encoded

# %%
import os
chemin_documents = os.path.expanduser('C:/Users/lydia/Documents/Datascientest/Projet fil rouge/CSV_files')
chemin_fichier_csv = os.path.join(chemin_documents, 'data_3.csv')
data_3.to_csv(chemin_fichier_csv, index=False)
